# %%
## Step 1: Import necessary packages 
from langchain_community.vectorstores import Chroma
from langchain_core.documents import Document
from langchain_huggingface import HuggingFaceEmbeddings
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
## Step 2: Define list of Documents (source documents)
documents = [
    Document(page_content = 'Document Loader loads the data from the data source.'),
    Document(page_content = 'Document is split into chunks via text-splitter.'),
    Document(page_content = 'Text-Splitter is converted into vector embeddings.'),
    Document(page_content = 'Vector Store store the vector embeddings.'),
    Document(page_content = 'Retriever fetches the data from vector store query which is called via invoke function.')
]

# %%
## Step 3: Define Embedding Model
model = HuggingFaceEmbeddings(model_name = 'all-MiniLM-L6-v2')
# Out:
# c:\Users\Aaryan Wadhawan\langchain-scripts\venv\Lib\site-packages\huggingface_hub\file_download.py:945: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
## Step 4: Store these embeddings into an vector store in memory
vectorStore = Chroma.from_documents(
    documents = documents,
    embedding = model,
    collection_name = 'rag_collection' 
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 2
#       1 ## Step 4: Store these embeddings into an vector store in memory
# ----> 2 vectorStore = Chroma.from_documents(
#       3     documents = documents,
#       4     embedding = model,
#       5     collection_name = 'rag_collection'
#       6 )
#
# File c:\Users\Aaryan Wadhawan\langchain-scripts\venv\Lib\site-packages\langchain_community\vectorstores\chroma.py:887, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     885 texts = [doc.page_content for doc in documents]
#     886 metadatas = [doc.metadata for doc in documents]
# --> 887 return cls.from_texts(
#     888     texts=texts,
#     889     embedding=embedding,
#     890     metadatas=metadatas,
#     891     ids=ids,
#     892     collection_name=collection_name,
#     893     persist_directory=persist_directory,
#     894     client_settings=client_settings,
#     895     client=client,
#     896     collection_metadata=collection_metadata,
#     897     **kwargs,
#     898 )
#
# File c:\Users\Aaryan Wadhawan\langchain-scripts\venv\Lib\site-packages\langchain_community\vectorstores\chroma.py:843, in Chroma.from_texts(cls, texts, embedding, metadatas, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     835     from chromadb.utils.batch_utils import create_batches
#     837     for batch in create_batches(
#     838         api=chroma_collection._client,
#     839         ids=ids,
#     840         metadatas=metadatas,
#     841         documents=texts,
#     842     ):
# --> 843         chroma_collection.add_texts(
#     844             texts=batch[3] if batch[3] else [],
#     845             metadatas=batch[2] if batch[2] else None,
#     846             ids=batch[0],
#     847         )
#     848 else:
#     849     chroma_collection.add_texts(texts=texts, metadatas=metadatas, ids=ids)
#
# File c:\Users\Aaryan Wadhawan\langchain-scripts\venv\Lib\site-packages\langchain_community\vectorstores\chroma.py:277, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     275 texts = list(texts)
#     276 if self._embedding_function is not None:
# --> 277     embeddings = self._embedding_function.embed_documents(texts)
#     278 if metadatas:
#     279     # fill metadatas with empty dicts if somebody
#     280     # did not specify metadata for all texts
#     281     length_diff = len(texts) - len(metadatas)
#
# File c:\Users\Aaryan Wadhawan\langchain-scripts\venv\Lib\site-packages\langchain_huggingface\embeddings\huggingface.py:156, in HuggingFaceEmbeddings.embed_documents(self, texts)
#     146 def embed_documents(self, texts: list[str]) -> list[list[float]]:
#     147     """Compute doc embeddings using a HuggingFace transformer model.
#     148
#     149     Args:
#    (...)    154
#     155     """
# --> 156     return self._embed(texts, self.encode_kwargs)
#
# File c:\Users\Aaryan Wadhawan\langchain-scripts\venv\Lib\site-packages\langchain_huggingface\embeddings\huggingface.py:131, in HuggingFaceEmbeddings._embed(self, texts, encode_kwargs)
#     129     sentence_transformers.SentenceTransformer.stop_multi_process_pool(pool)
#     130 else:
# --> 131     embeddings = self._client.encode(
#     132         texts,
#     133         show_progress_bar=self.show_progress,
#     134         **encode_kwargs,
#     135     )
#     137 if isinstance(embeddings, list):
#     138     msg = (
#     139         "Expected embeddings to be a Tensor or a numpy array, "
#     140         "got a list instead."
#     141     )
#
# File c:\Users\Aaryan Wadhawan\langchain-scripts\venv\Lib\site-packages\sentence_transformers\SentenceTransformer.py:568, in SentenceTransformer.encode(self, sentences, prompt_name, prompt, batch_size, show_progress_bar, output_value, precision, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     566             all_embeddings = np.asarray([emb.float().numpy() for emb in all_embeddings])
#     567         else:
# --> 568             all_embeddings = np.asarray([emb.numpy() for emb in all_embeddings])
#     569 elif isinstance(all_embeddings, np.ndarray):
#     570     all_embeddings = [torch.from_numpy(embedding) for embedding in all_embeddings]
#
# RuntimeError: Numpy is not available

# %%
## Step 5: Convert vector into an retriever
retriever = vectorStore.as_retriever(search_kwargs = {"k" : 1})

# %%
## Step 6: Pass query to retriever
query = 'How is document is converted into chunks?'
result = retriever.invoke(query)

# %%
for i, doc in enumerate(result):
    print (f"\n-----Result {i+1}-----")
    print (f"\n{doc.page_content}")

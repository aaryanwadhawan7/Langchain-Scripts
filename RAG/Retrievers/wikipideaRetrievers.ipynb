# %%
from langchain_community.retrievers import WikipediaRetriever

# %%
## Initialize the Retriever [Optional: set language and top_k]
retriever = WikipediaRetriever(top_k_results = 2, lang = 'en')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File c:\Users\Aaryan Wadhawan\langchain-scripts\venv\Lib\site-packages\langchain_community\utilities\wikipedia.py:35, in WikipediaAPIWrapper.validate_environment(cls, values)
#      34 try:
# ---> 35     import wikipedia
#      37     lang = values.get("lang", "en")
#
# ModuleNotFoundError: No module named 'wikipedia'
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 2
#       1 ## Initialize the Retriever [Optional: set language and top_k]
# ----> 2 retriever = WikipediaRetriever(top_k_results = 2, lang = 'en')
#
# File c:\Users\Aaryan Wadhawan\langchain-scripts\venv\Lib\site-packages\langchain_core\load\serializable.py:115, in Serializable.__init__(self, *args, **kwargs)
#     113 def __init__(self, *args: Any, **kwargs: Any) -> None:
#     114     """"""  # noqa: D419  # Intentional blank docstring
# --> 115     super().__init__(*args, **kwargs)
#
#     [... skipping hidden 1 frame]
#
# File c:\Users\Aaryan Wadhawan\langchain-scripts\venv\Lib\site-packages\langchain_community\utilities\wikipedia.py:41, in WikipediaAPIWrapper.validate_environment(cls, values)
#      39     values["wiki_client"] = wikipedia
#      40 except ImportError:
# ---> 41     raise ImportError(
#      42         "Could not import wikipedia python package. "
#      43         "Please install it with `pip install wikipedia`."
#      44     )
#      45 return values
#
# ImportError: Could not import wikipedia python package. Please install it with `pip install wikipedia`.

# %%
## Define the query
query = 'State some facts about Cristiano Ronaldo.'

## Since Retrievers are Runnables, we can call invoke function
docs = retriever.invoke(query)

for i, doc in enumerate(docs):
    print (f"-----Result {i+1}-----")
    print (f"Content:\n{doc.page_content}")
